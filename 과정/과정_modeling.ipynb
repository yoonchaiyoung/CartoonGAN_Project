# %% [markdown]
# # CartoonGAN 논문의 모델 구조
# <img src="https://aruie.github.io/assets/post/191114-01.png" width=700>

# %% [markdown]
# # generator - 방법 2 사용!
# - 초기화 단계 : 10 epoch만큼 먼저 훈련

# %% [markdown]
# ## input
# - resizing된 사진 (resizing 함수를 이용하여 300x300으로 미리 resizing)

# %%
# Google Drive mount
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 참고 : https://www.tensorflow.org/api_docs

# %%
# 사진 있는 디렉토리 위치
photo_path = '/content/drive/MyDrive/GoogleColab/CartoonGAN_Project/data/photo_data'

# 사진 파일명 리스트 저장
photoName_list = os.listdir(photo_path)
print(photoName_list[:10])  # 앞의 10개만 파일명 보기
print(len(photoName_list))  # 사진 총 몇 장 있는 지 보기
# Out:
# ['50817142731_dfc154ea75_o.jpg', '50819927577_2286b936e1_k.jpg', '50817727238_b7f3f5acd9_o.jpg', '50821206327_ea91c5e259_o.jpg', '50820323176_60016143b1_o.jpg', '40882481714_50b8a7490e_o.jpg', '44926777104_4ed4b51861_o.jpg', '27585811288_40d99dc08e_o.jpg', '5508784414_3ec3992ddc_o.jpg', '25690386427_7ef979d9ab_k.jpg']
# 43

# %% [markdown]
# ## 모델링

# %%
# 네트워크를 만들 땐
# 1. sequential 모델을 사용한 네트워크
# 2. 함수형 API를 사용한 네트워크

# 2가지 방법으로 만들 수 있다.

# 1번 방법 ->  일렬로 층을 쌓은 네트워크를 빠르게 만들 때 사용하기 좋다.
# 2번 방법 -> 한 층의 출력이 여러 개의 별도의 층으로 전달되는 네트워크를 만들 때 유연성있게 만들기 좋다.
#          -> 심층 신경망 구조를 설계하는데 자유롭다.

# %%
# residual block은 똑같은 구조가 generator안에 8번 반복되므로 함수로 따로 만들자.
def generator_residual_block(x):
  shortcut = x
  x = Conv2D(kernel_size = 3,
            filters = 256,
            strides = 1,
            padding = "same"
            )(x)
  x = BatchNormalization()(x)
  x = ReLU()(x)
  x = Conv2D(kernel_size = 3,
            filters = 256,
            strides = 1,
            padding = "same")(x)
  x = BatchNormalization()(x)
  x = layers.Add()([x, shortcut])  # identity shortcut connection  # elementwise sum
  
  return x

# %% [markdown]
# up-convolution 영역
# 1. UpSampling2D + Conv2D
# 2. Conv2DTranspose
# - 두 가지 방법 다 사용해보고 어떤 것이 좋은 결과가 나오는 지 직접 확인해보고 결정해야함
#
#
# - UpSampling2D docs 참고 : https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D
# - Conv2DTranspose docs 참고 : https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose

# %% [markdown]
# ## 방법 1 - UpSampling2D + Conv2D 이용

# %%
# 우선 input에 사진 이미지를 넣지 않고 숫자만 넣고
# 틀만 짜보자.

input_shape1 = (300, 300, 3)

input_layer1 = Input(shape = input_shape1)  # resizing된 사진 넣기

# flat-convolution 영역
net1 = Conv2D(kernel_size = 7,
              filters = 64,
              strides = 1,
              padding = "same"
              )(input_layer1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

# down-convolution 영역
net1 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 2,
              padding = "same"
              )(net1)

net1 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

net1 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 2,
              padding = "same"
              )(net1)
net1 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

# 8 residual block 영역
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)

# up-convolution 영역
net1 = UpSampling2D(size = (2, 2)
                    )(net1)
net1 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

net1 = UpSampling2D(size = (2, 2)
                    )(net1)
net1 = Conv2D(kernel_size = 3,
              filters = 64,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = LeakyReLU()(net1)

# output layer 영역
net1 = Conv2D(kernel_size = 7,
              filters = 3,
              strides = 1,
              padding = "same"
              )(net1)

# %%
model1 = Model(inputs = input_layer1,
               outputs = net1,
               name = "generator1")
model1.summary()
# Out:
# Model: "generator1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 300, 300, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 300, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 300, 300, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 128 73856       re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 150, 150, 128 147584      conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150, 150, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 150, 150, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 75, 75, 256)  295168      re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 256)  590080      conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 75, 75, 256)  590080      re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 75, 75, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 75, 75, 256)  590080      re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 75, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 75, 75, 256)  0           batch_normalization_4[0][0]
#                                                                  re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 256)  590080      add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 75, 75, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 256)  590080      re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 75, 75, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 75, 256)  0           batch_normalization_6[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 256)  590080      add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 75, 75, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 75, 75, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 75, 256)  0           batch_normalization_8[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 256)  590080      add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 75, 75, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 75, 75, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 75, 75, 256)  0           batch_normalization_10[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 256)  590080      add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 75, 75, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 75, 75, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 75, 75, 256)  0           batch_normalization_12[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 75, 75, 256)  590080      add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 75, 75, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 75, 75, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 75, 75, 256)  0           batch_normalization_14[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 256)  590080      add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 75, 75, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 75, 75, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 75, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 75, 75, 256)  0           batch_normalization_16[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 256)  590080      add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 75, 75, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 75, 75, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 75, 75, 256)  0           batch_normalization_18[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 150, 150, 256 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 150, 150, 128 295040      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 150, 128 512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 150, 150, 128 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 300, 300, 128 0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 300, 300, 64) 73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 300, 64) 256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 300, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 300, 300, 3)  9411        leaky_re_lu[0][0]
# ==================================================================================================
# Total params: 10,954,627
# Trainable params: 10,945,155
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 출력 shape : (None, 300, 300, 3)
# 300x300 의 컬러 이미지로 잘 나오는 것 확인.

# %% [markdown]
# ## 방법 2 - Conv2DTranspose 이용

# %%
# 우선 input에 사진 이미지를 넣지 않고 숫자만 넣고
# 틀만 짜보자.

input_shape2 = (300, 300, 3)

input_layer2 = Input(shape = input_shape2)  # resizing된 사진 넣기

# flat-convolution 영역
net2 = Conv2D(kernel_size = 7,
              filters = 64,
              strides = 1,
              padding = "same"
              )(input_layer2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

# down-convolution 영역
net2 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 2,
              padding = "same"
              )(net2)

net2 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

net2 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 2,
              padding = "same"
              )(net2)
net2 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

# 8 residual block 영역
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)

# up-convolution 영역
net2 = Conv2DTranspose(kernel_size = 3,
                       filters = 128,
                       strides = (2, 2),
                       padding = "same"
                       )(net2)
net2 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

net2 = Conv2DTranspose(kernel_size = 3,
                       filters = 64,
                       strides = (2, 2),
                       padding = "same"
                       )(net2)
net2 = Conv2D(kernel_size = 3,
              filters = 64,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = LeakyReLU()(net2)

# output layer 영역
net2 = Conv2D(kernel_size = 7,
              filters = 3,
              strides = 1,
              padding = "same"
              )(net2)

# %%
model2 = Model(inputs = input_layer2,
              outputs = net2,
              name = "generator2")
model2.summary()
# Out:
# Model: "generator2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 300, 300, 64) 9472        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 300, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 300, 300, 64) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 150, 150, 128 73856       re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 150, 150, 128 147584      conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 150, 128 512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 150, 150, 128 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 75, 75, 256)  295168      re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 75, 75, 256)  590080      conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 75, 75, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 75, 75, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 75, 75, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 75, 75, 256)  0           batch_normalization_25[0][0]
#                                                                  re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 75, 75, 256)  590080      add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 75, 75, 256)  1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 75, 75, 256)  1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 75, 75, 256)  0           batch_normalization_27[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 75, 75, 256)  590080      add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 75, 75, 256)  1024        conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 75, 75, 256)  1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 75, 75, 256)  0           batch_normalization_29[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 75, 75, 256)  590080      add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 75, 75, 256)  1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 75, 75, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 75, 75, 256)  0           batch_normalization_31[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 75, 75, 256)  590080      add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 75, 75, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 75, 75, 256)  1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 75, 75, 256)  0           batch_normalization_33[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 75, 75, 256)  590080      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 75, 75, 256)  1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 75, 75, 256)  1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 75, 75, 256)  0           batch_normalization_35[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 75, 75, 256)  590080      add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 75, 75, 256)  1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 75, 75, 256)  1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 75, 75, 256)  0           batch_normalization_37[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 75, 75, 256)  590080      add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 75, 75, 256)  1024        conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 75, 75, 256)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 75, 75, 256)  590080      re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 75, 75, 256)  1024        conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 75, 75, 256)  0           batch_normalization_39[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 150, 150, 128 295040      add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 150, 150, 128 147584      conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 150, 128 512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 150, 150, 128 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 300, 300, 64) 73792       re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 300, 300, 64) 36928       conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 300, 64) 256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 300, 64) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 300, 300, 3)  9411        leaky_re_lu_1[0][0]
# ==================================================================================================
# Total params: 11,139,139
# Trainable params: 11,129,667
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 출력 shape : (None, 300, 300, 3)
# 300x300 의 컬러 이미지로 잘 나오는 것 확인.

# %% [markdown]
# 그렇다면 방법 1 - UpSampling2D + Conv2D를 사용하는 방법과
#
# 방법 2 - Conv2DTranspose를 사용하는 방법 중 어떤 것을 사용해야 적절할까?
#
# <img src="https://aruie.github.io/assets/post/191114-01.png" width=700>
#
# 이와 같이 논문에서 나오는 모델의 구조를 보면
#
# kernel_size, filters, strides가 다 디테일하게 나와있다.
#
# 그러므로 kernel_size, filters에 대해서는 파라미터 조정을 해줄 수 없는 방법 1의 UpSampling2D를 사용하는 것보다
#
# kernel_size, filters, strides에 대해 파라미터 조정을 다 해줄 수 있는 방법 2의 Conv2DTranspose를 사용하는 방법이 더 적절해보인다!

# %% [markdown]
# ## 방법 1, 방법 2 중 어떤 것 사용? -> 방법 2 사용

# %% [markdown]
# ## compile

# %%
# generator 컴파일
model2.compile(loss=loss, optimizer=optimizer, metrics=metrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5ecfd7beb2fa> in <module>()
#       1 # generator 컴파일
# ----> 2 model2.compile(loss=loss, optimizer=optimizer, metrics=metrics)
#
# NameError: name 'loss' is not defined

# %% [markdown]
# # discriminator

# %% [markdown]
# ## input
# - 사진
# - 엣지 smoothing된 만화 이미지
# - 카툰화된 사진

# %% [markdown]
# ## 모델링

# %%
# 우선 input에 사진 이미지를 넣지 않고 숫자만 넣고
# 틀만 짜보자.
input_shape3 = (300, 300, 3)
input_layer3 = Input(input_shape3)  # 사진, 엣지 smoothing된 만화 이미지, 카툰화된 사진이 들어옴

net3 = Conv2D(kernel_size = 3,
              filters = 32,
              strides = 1,
              padding = "same"
              )(input_layer3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 64,
              strides = 2,
              padding = "same"
              )(net3)
net3 = LeakyReLU(alpha=0.2)(net3)
net3 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net3)
net3 = BatchNormalization()(net3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 2,
              padding = "same"
              )(net3)
net3 = LeakyReLU(alpha=0.2)(net3)
net3 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net3)
net3 = BatchNormalization()(net3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net3)
net3 = BatchNormalization()(net3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 1,
              strides = 1,
              padding = "same"
              )(net3)

# %%
model3 = Model(inputs = input_layer3,
              outputs = net3,
              name = "discriminator")
model3.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 300, 300, 32)      896
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 300, 300, 32)      0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 150, 150, 64)      18496
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 150, 150, 64)      0
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 150, 150, 128)     73856
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 150, 150, 128)     512
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 150, 150, 128)     0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 75, 75, 128)       0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 75, 75, 256)       295168
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 75, 75, 256)       1024
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 75, 75, 256)       0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 75, 75, 256)       590080
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 75, 75, 256)       1024
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 75, 75, 256)       0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 75, 75, 1)         2305
# =================================================================
# Total params: 1,130,945
# Trainable params: 1,129,665
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
# 출력 shape : (None, 75, 75, 1)

# compile
model3.compile(loss = loss, optimizer = optimizer, metrics = metrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e87b2ff29652> in <module>()
#       2
#       3 # compile
# ----> 4 model3.compile(loss = loss, optimizer = optimizer, metrics = metrics)
#
# NameError: name 'loss' is not defined

# %% [markdown]
# # generator_web
# - 위의 generator를 훈련 데이터로 학습을 시킨 후, 그 가중치를 피클로 저장하여 generator_web만 서버에 올린다!
