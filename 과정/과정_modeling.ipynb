# %% [markdown]
# # CartoonGAN 논문의 모델 구조
# <img src="https://aruie.github.io/assets/post/191114-01.png" width=700>

# %% [markdown]
# # generator - 방법 2 사용!
# - 초기화 단계 : 10 epoch만큼 먼저 훈련

# %% [markdown]
# ## input
# - resizing된 사진 (resizing 함수를 이용하여 300x300으로 미리 resizing)

# %%
# Google Drive mount
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 참고 : https://www.tensorflow.org/api_docs

# %%
# 사진 있는 디렉토리 위치
photo_path = '/content/drive/MyDrive/GoogleColab/CartoonGAN_Project/data/photo_data'

# 사진 파일명 리스트 저장
photoName_list = os.listdir(photo_path)
print(photoName_list[:10])  # 앞의 10개만 파일명 보기
print(len(photoName_list))  # 사진 총 몇 장 있는 지 보기
# Out:
# ['50817142731_dfc154ea75_o.jpg', '50819927577_2286b936e1_k.jpg', '50817727238_b7f3f5acd9_o.jpg', '50821206327_ea91c5e259_o.jpg', '50820323176_60016143b1_o.jpg', '40882481714_50b8a7490e_o.jpg', '44926777104_4ed4b51861_o.jpg', '27585811288_40d99dc08e_o.jpg', '5508784414_3ec3992ddc_o.jpg', '25690386427_7ef979d9ab_k.jpg']
# 43

# %% [markdown]
# ## 모델링

# %%
# 네트워크를 만들 땐
# 1. sequential 모델을 사용한 네트워크
# 2. 함수형 API를 사용한 네트워크

# 2가지 방법으로 만들 수 있다.

# 1번 방법 ->  일렬로 층을 쌓은 네트워크를 빠르게 만들 때 사용하기 좋다.
# 2번 방법 -> 한 층의 출력이 여러 개의 별도의 층으로 전달되는 네트워크를 만들 때 유연성있게 만들기 좋다.
#          -> 심층 신경망 구조를 설계하는데 자유롭다.

# %%
# residual block은 똑같은 구조가 generator안에 8번 반복되므로 함수로 따로 만들자.
def generator_residual_block(x):
  shortcut = x
  x = Conv2D(kernel_size = 3,
            filters = 256,
            strides = 1,
            padding = "same"
            )(x)
  x = BatchNormalization()(x)
  x = ReLU()(x)
  x = Conv2D(kernel_size = 3,
            filters = 256,
            strides = 1,
            padding = "same")(x)
  x = BatchNormalization()(x)
  x = layers.Add()([x, shortcut])  # identity shortcut connection  # elementwise sum
  
  return x

# %% [markdown]
# up-convolution 영역
# 1. UpSampling2D + Conv2D
# 2. Conv2DTranspose
# - 두 가지 방법 다 사용해보고 어떤 것이 좋은 결과가 나오는 지 직접 확인해보고 결정해야함
#
#
# - UpSampling2D docs 참고 : https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D
# - Conv2DTranspose docs 참고 : https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose

# %% [markdown]
# ## 방법 1 - UpSampling2D + Conv2D 이용

# %%
# 우선 input에 사진 이미지를 넣지 않고 숫자만 넣고
# 틀만 짜보자.

input_shape1 = (300, 300, 3)

input_layer1 = Input(shape = input_shape1)  # resizing된 사진 넣기

# flat-convolution 영역
net1 = Conv2D(kernel_size = 7,
              filters = 64,
              strides = 1,
              padding = "same"
              )(input_layer1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

# down-convolution 영역
net1 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 2,
              padding = "same"
              )(net1)

net1 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

net1 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 2,
              padding = "same"
              )(net1)
net1 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

# 8 residual block 영역
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)
net1 = generator_residual_block(net1)

# up-convolution 영역
net1 = UpSampling2D(size = (2, 2)
                    )(net1)
net1 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = ReLU()(net1)

net1 = UpSampling2D(size = (2, 2)
                    )(net1)
net1 = Conv2D(kernel_size = 3,
              filters = 64,
              strides = 1,
              padding = "same"
              )(net1)
net1 = BatchNormalization()(net1)
net1 = LeakyReLU()(net1)

# output layer 영역
net1 = Conv2D(kernel_size = 7,
              filters = 3,
              strides = 1,
              padding = "same"
              )(net1)

# %%
model1 = Model(inputs = input_layer1,
               outputs = net1,
               name = "generator1")
model1.summary()
# Out:
# Model: "generator1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_31 (InputLayer)           [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d_614 (Conv2D)             (None, 300, 300, 64) 9472        input_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_519 (BatchN (None, 300, 300, 64) 256         conv2d_614[0][0]
# __________________________________________________________________________________________________
# re_lu_287 (ReLU)                (None, 300, 300, 64) 0           batch_normalization_519[0][0]
# __________________________________________________________________________________________________
# conv2d_615 (Conv2D)             (None, 150, 150, 128 73856       re_lu_287[0][0]
# __________________________________________________________________________________________________
# conv2d_616 (Conv2D)             (None, 150, 150, 128 147584      conv2d_615[0][0]
# __________________________________________________________________________________________________
# batch_normalization_520 (BatchN (None, 150, 150, 128 512         conv2d_616[0][0]
# __________________________________________________________________________________________________
# re_lu_288 (ReLU)                (None, 150, 150, 128 0           batch_normalization_520[0][0]
# __________________________________________________________________________________________________
# conv2d_617 (Conv2D)             (None, 75, 75, 256)  295168      re_lu_288[0][0]
# __________________________________________________________________________________________________
# conv2d_618 (Conv2D)             (None, 75, 75, 256)  590080      conv2d_617[0][0]
# __________________________________________________________________________________________________
# batch_normalization_521 (BatchN (None, 75, 75, 256)  1024        conv2d_618[0][0]
# __________________________________________________________________________________________________
# re_lu_289 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_521[0][0]
# __________________________________________________________________________________________________
# conv2d_619 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_289[0][0]
# __________________________________________________________________________________________________
# batch_normalization_522 (BatchN (None, 75, 75, 256)  1024        conv2d_619[0][0]
# __________________________________________________________________________________________________
# re_lu_290 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_522[0][0]
# __________________________________________________________________________________________________
# conv2d_620 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_523 (BatchN (None, 75, 75, 256)  1024        conv2d_620[0][0]
# __________________________________________________________________________________________________
# add_192 (Add)                   (None, 75, 75, 256)  0           batch_normalization_523[0][0]
#                                                                  re_lu_289[0][0]
# __________________________________________________________________________________________________
# conv2d_621 (Conv2D)             (None, 75, 75, 256)  590080      add_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_524 (BatchN (None, 75, 75, 256)  1024        conv2d_621[0][0]
# __________________________________________________________________________________________________
# re_lu_291 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_524[0][0]
# __________________________________________________________________________________________________
# conv2d_622 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_525 (BatchN (None, 75, 75, 256)  1024        conv2d_622[0][0]
# __________________________________________________________________________________________________
# add_193 (Add)                   (None, 75, 75, 256)  0           batch_normalization_525[0][0]
#                                                                  add_192[0][0]
# __________________________________________________________________________________________________
# conv2d_623 (Conv2D)             (None, 75, 75, 256)  590080      add_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_526 (BatchN (None, 75, 75, 256)  1024        conv2d_623[0][0]
# __________________________________________________________________________________________________
# re_lu_292 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_526[0][0]
# __________________________________________________________________________________________________
# conv2d_624 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_292[0][0]
# __________________________________________________________________________________________________
# batch_normalization_527 (BatchN (None, 75, 75, 256)  1024        conv2d_624[0][0]
# __________________________________________________________________________________________________
# add_194 (Add)                   (None, 75, 75, 256)  0           batch_normalization_527[0][0]
#                                                                  add_193[0][0]
# __________________________________________________________________________________________________
# conv2d_625 (Conv2D)             (None, 75, 75, 256)  590080      add_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_528 (BatchN (None, 75, 75, 256)  1024        conv2d_625[0][0]
# __________________________________________________________________________________________________
# re_lu_293 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_528[0][0]
# __________________________________________________________________________________________________
# conv2d_626 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_529 (BatchN (None, 75, 75, 256)  1024        conv2d_626[0][0]
# __________________________________________________________________________________________________
# add_195 (Add)                   (None, 75, 75, 256)  0           batch_normalization_529[0][0]
#                                                                  add_194[0][0]
# __________________________________________________________________________________________________
# conv2d_627 (Conv2D)             (None, 75, 75, 256)  590080      add_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_530 (BatchN (None, 75, 75, 256)  1024        conv2d_627[0][0]
# __________________________________________________________________________________________________
# re_lu_294 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_530[0][0]
# __________________________________________________________________________________________________
# conv2d_628 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_531 (BatchN (None, 75, 75, 256)  1024        conv2d_628[0][0]
# __________________________________________________________________________________________________
# add_196 (Add)                   (None, 75, 75, 256)  0           batch_normalization_531[0][0]
#                                                                  add_195[0][0]
# __________________________________________________________________________________________________
# conv2d_629 (Conv2D)             (None, 75, 75, 256)  590080      add_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_532 (BatchN (None, 75, 75, 256)  1024        conv2d_629[0][0]
# __________________________________________________________________________________________________
# re_lu_295 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_532[0][0]
# __________________________________________________________________________________________________
# conv2d_630 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_295[0][0]
# __________________________________________________________________________________________________
# batch_normalization_533 (BatchN (None, 75, 75, 256)  1024        conv2d_630[0][0]
# __________________________________________________________________________________________________
# add_197 (Add)                   (None, 75, 75, 256)  0           batch_normalization_533[0][0]
#                                                                  add_196[0][0]
# __________________________________________________________________________________________________
# conv2d_631 (Conv2D)             (None, 75, 75, 256)  590080      add_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_534 (BatchN (None, 75, 75, 256)  1024        conv2d_631[0][0]
# __________________________________________________________________________________________________
# re_lu_296 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_534[0][0]
# __________________________________________________________________________________________________
# conv2d_632 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_535 (BatchN (None, 75, 75, 256)  1024        conv2d_632[0][0]
# __________________________________________________________________________________________________
# add_198 (Add)                   (None, 75, 75, 256)  0           batch_normalization_535[0][0]
#                                                                  add_197[0][0]
# __________________________________________________________________________________________________
# conv2d_633 (Conv2D)             (None, 75, 75, 256)  590080      add_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_536 (BatchN (None, 75, 75, 256)  1024        conv2d_633[0][0]
# __________________________________________________________________________________________________
# re_lu_297 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_536[0][0]
# __________________________________________________________________________________________________
# conv2d_634 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_537 (BatchN (None, 75, 75, 256)  1024        conv2d_634[0][0]
# __________________________________________________________________________________________________
# add_199 (Add)                   (None, 75, 75, 256)  0           batch_normalization_537[0][0]
#                                                                  add_198[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 150, 150, 256 0           add_199[0][0]
# __________________________________________________________________________________________________
# conv2d_635 (Conv2D)             (None, 150, 150, 128 295040      up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_538 (BatchN (None, 150, 150, 128 512         conv2d_635[0][0]
# __________________________________________________________________________________________________
# re_lu_298 (ReLU)                (None, 150, 150, 128 0           batch_normalization_538[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 300, 300, 128 0           re_lu_298[0][0]
# __________________________________________________________________________________________________
# conv2d_636 (Conv2D)             (None, 300, 300, 64) 73792       up_sampling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_539 (BatchN (None, 300, 300, 64) 256         conv2d_636[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 300, 300, 64) 0           batch_normalization_539[0][0]
# __________________________________________________________________________________________________
# conv2d_637 (Conv2D)             (None, 300, 300, 3)  9411        leaky_re_lu_58[0][0]
# ==================================================================================================
# Total params: 10,954,627
# Trainable params: 10,945,155
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 출력 shape : (None, 300, 300, 3)
# 300x300 의 컬러 이미지로 잘 나오는 것 확인.

# %% [markdown]
# ## 방법 2 - Conv2DTranspose 이용

# %%
# 우선 input에 사진 이미지를 넣지 않고 숫자만 넣고
# 틀만 짜보자.

input_shape2 = (300, 300, 3)

input_layer2 = Input(shape = input_shape2)  # resizing된 사진 넣기

# flat-convolution 영역
net2 = Conv2D(kernel_size = 7,
              filters = 64,
              strides = 1,
              padding = "same"
              )(input_layer2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

# down-convolution 영역
net2 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 2,
              padding = "same"
              )(net2)

net2 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

net2 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 2,
              padding = "same"
              )(net2)
net2 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

# 8 residual block 영역
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)
net2 = generator_residual_block(net2)

# up-convolution 영역
net2 = Conv2DTranspose(kernel_size = 3,
                       filters = 128,
                       strides = (2, 2),
                       padding = "same"
                       )(net2)
net2 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = ReLU()(net2)

net2 = Conv2DTranspose(kernel_size = 3,
                       filters = 64,
                       strides = (2, 2),
                       padding = "same"
                       )(net2)
net2 = Conv2D(kernel_size = 3,
              filters = 64,
              strides = 1,
              padding = "same"
              )(net2)
net2 = BatchNormalization()(net2)
net2 = LeakyReLU()(net2)

# output layer 영역
net2 = Conv2D(kernel_size = 7,
              filters = 3,
              strides = 1,
              padding = "same"
              )(net2)

# %%
model2 = Model(inputs = input_layer2,
              outputs = net2,
              name = "generator2")
model2.summary()
# Out:
# Model: "generator2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_32 (InputLayer)           [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d_638 (Conv2D)             (None, 300, 300, 64) 9472        input_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_540 (BatchN (None, 300, 300, 64) 256         conv2d_638[0][0]
# __________________________________________________________________________________________________
# re_lu_299 (ReLU)                (None, 300, 300, 64) 0           batch_normalization_540[0][0]
# __________________________________________________________________________________________________
# conv2d_639 (Conv2D)             (None, 150, 150, 128 73856       re_lu_299[0][0]
# __________________________________________________________________________________________________
# conv2d_640 (Conv2D)             (None, 150, 150, 128 147584      conv2d_639[0][0]
# __________________________________________________________________________________________________
# batch_normalization_541 (BatchN (None, 150, 150, 128 512         conv2d_640[0][0]
# __________________________________________________________________________________________________
# re_lu_300 (ReLU)                (None, 150, 150, 128 0           batch_normalization_541[0][0]
# __________________________________________________________________________________________________
# conv2d_641 (Conv2D)             (None, 75, 75, 256)  295168      re_lu_300[0][0]
# __________________________________________________________________________________________________
# conv2d_642 (Conv2D)             (None, 75, 75, 256)  590080      conv2d_641[0][0]
# __________________________________________________________________________________________________
# batch_normalization_542 (BatchN (None, 75, 75, 256)  1024        conv2d_642[0][0]
# __________________________________________________________________________________________________
# re_lu_301 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_542[0][0]
# __________________________________________________________________________________________________
# conv2d_643 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_543 (BatchN (None, 75, 75, 256)  1024        conv2d_643[0][0]
# __________________________________________________________________________________________________
# re_lu_302 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_543[0][0]
# __________________________________________________________________________________________________
# conv2d_644 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_544 (BatchN (None, 75, 75, 256)  1024        conv2d_644[0][0]
# __________________________________________________________________________________________________
# add_200 (Add)                   (None, 75, 75, 256)  0           batch_normalization_544[0][0]
#                                                                  re_lu_301[0][0]
# __________________________________________________________________________________________________
# conv2d_645 (Conv2D)             (None, 75, 75, 256)  590080      add_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_545 (BatchN (None, 75, 75, 256)  1024        conv2d_645[0][0]
# __________________________________________________________________________________________________
# re_lu_303 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_545[0][0]
# __________________________________________________________________________________________________
# conv2d_646 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_546 (BatchN (None, 75, 75, 256)  1024        conv2d_646[0][0]
# __________________________________________________________________________________________________
# add_201 (Add)                   (None, 75, 75, 256)  0           batch_normalization_546[0][0]
#                                                                  add_200[0][0]
# __________________________________________________________________________________________________
# conv2d_647 (Conv2D)             (None, 75, 75, 256)  590080      add_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_547 (BatchN (None, 75, 75, 256)  1024        conv2d_647[0][0]
# __________________________________________________________________________________________________
# re_lu_304 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_547[0][0]
# __________________________________________________________________________________________________
# conv2d_648 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_548 (BatchN (None, 75, 75, 256)  1024        conv2d_648[0][0]
# __________________________________________________________________________________________________
# add_202 (Add)                   (None, 75, 75, 256)  0           batch_normalization_548[0][0]
#                                                                  add_201[0][0]
# __________________________________________________________________________________________________
# conv2d_649 (Conv2D)             (None, 75, 75, 256)  590080      add_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_549 (BatchN (None, 75, 75, 256)  1024        conv2d_649[0][0]
# __________________________________________________________________________________________________
# re_lu_305 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_549[0][0]
# __________________________________________________________________________________________________
# conv2d_650 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_550 (BatchN (None, 75, 75, 256)  1024        conv2d_650[0][0]
# __________________________________________________________________________________________________
# add_203 (Add)                   (None, 75, 75, 256)  0           batch_normalization_550[0][0]
#                                                                  add_202[0][0]
# __________________________________________________________________________________________________
# conv2d_651 (Conv2D)             (None, 75, 75, 256)  590080      add_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_551 (BatchN (None, 75, 75, 256)  1024        conv2d_651[0][0]
# __________________________________________________________________________________________________
# re_lu_306 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_551[0][0]
# __________________________________________________________________________________________________
# conv2d_652 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_552 (BatchN (None, 75, 75, 256)  1024        conv2d_652[0][0]
# __________________________________________________________________________________________________
# add_204 (Add)                   (None, 75, 75, 256)  0           batch_normalization_552[0][0]
#                                                                  add_203[0][0]
# __________________________________________________________________________________________________
# conv2d_653 (Conv2D)             (None, 75, 75, 256)  590080      add_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_553 (BatchN (None, 75, 75, 256)  1024        conv2d_653[0][0]
# __________________________________________________________________________________________________
# re_lu_307 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_553[0][0]
# __________________________________________________________________________________________________
# conv2d_654 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_307[0][0]
# __________________________________________________________________________________________________
# batch_normalization_554 (BatchN (None, 75, 75, 256)  1024        conv2d_654[0][0]
# __________________________________________________________________________________________________
# add_205 (Add)                   (None, 75, 75, 256)  0           batch_normalization_554[0][0]
#                                                                  add_204[0][0]
# __________________________________________________________________________________________________
# conv2d_655 (Conv2D)             (None, 75, 75, 256)  590080      add_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_555 (BatchN (None, 75, 75, 256)  1024        conv2d_655[0][0]
# __________________________________________________________________________________________________
# re_lu_308 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_555[0][0]
# __________________________________________________________________________________________________
# conv2d_656 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_556 (BatchN (None, 75, 75, 256)  1024        conv2d_656[0][0]
# __________________________________________________________________________________________________
# add_206 (Add)                   (None, 75, 75, 256)  0           batch_normalization_556[0][0]
#                                                                  add_205[0][0]
# __________________________________________________________________________________________________
# conv2d_657 (Conv2D)             (None, 75, 75, 256)  590080      add_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_557 (BatchN (None, 75, 75, 256)  1024        conv2d_657[0][0]
# __________________________________________________________________________________________________
# re_lu_309 (ReLU)                (None, 75, 75, 256)  0           batch_normalization_557[0][0]
# __________________________________________________________________________________________________
# conv2d_658 (Conv2D)             (None, 75, 75, 256)  590080      re_lu_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_558 (BatchN (None, 75, 75, 256)  1024        conv2d_658[0][0]
# __________________________________________________________________________________________________
# add_207 (Add)                   (None, 75, 75, 256)  0           batch_normalization_558[0][0]
#                                                                  add_206[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 150, 150, 128 295040      add_207[0][0]
# __________________________________________________________________________________________________
# conv2d_659 (Conv2D)             (None, 150, 150, 128 147584      conv2d_transpose_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_559 (BatchN (None, 150, 150, 128 512         conv2d_659[0][0]
# __________________________________________________________________________________________________
# re_lu_310 (ReLU)                (None, 150, 150, 128 0           batch_normalization_559[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 300, 300, 64) 73792       re_lu_310[0][0]
# __________________________________________________________________________________________________
# conv2d_660 (Conv2D)             (None, 300, 300, 64) 36928       conv2d_transpose_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_560 (BatchN (None, 300, 300, 64) 256         conv2d_660[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 300, 300, 64) 0           batch_normalization_560[0][0]
# __________________________________________________________________________________________________
# conv2d_661 (Conv2D)             (None, 300, 300, 3)  9411        leaky_re_lu_59[0][0]
# ==================================================================================================
# Total params: 11,139,139
# Trainable params: 11,129,667
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 출력 shape : (None, 300, 300, 3)
# 300x300 의 컬러 이미지로 잘 나오는 것 확인.

# %% [markdown]
# 그렇다면 방법 1 - UpSampling2D + Conv2D를 사용하는 방법과
#
# 방법 2 - Conv2DTranspose를 사용하는 방법 중 어떤 것을 사용해야 적절할까?
#
# <img src="https://aruie.github.io/assets/post/191114-01.png" width=700>
#
# 이와 같이 논문에서 나오는 모델의 구조를 보면
#
# kernel_size, filters, strides가 다 디테일하게 나와있다.
#
# 그러므로 kernel_size, filters에 대해서는 파라미터 조정을 해줄 수 없는 방법 1의 UpSampling2D를 사용하는 것보다
#
# kernel_size, filters, strides에 대해 파라미터 조정을 다 해줄 수 있는 방법 2의 Conv2DTranspose를 사용하는 방법이 더 적절해보인다!

# %% [markdown]
# ## 방법 1, 방법 2 중 어떤 것 사용? -> 방법 2 사용

# %% [markdown]
# ## compile

# %%
# generator 컴파일
model2.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %% [markdown]
# # discriminator

# %% [markdown]
# ## input
# - 사진
# - 엣지 smoothing된 만화 이미지
# - 카툰화된 사진

# %% [markdown]
# ## 모델링

# %%
# 우선 input에 사진 이미지를 넣지 않고 숫자만 넣고
# 틀만 짜보자.
input_shape3 = (300, 300, 3)
input_layer3 = Input(input_shape3)  # 사진, 엣지 smoothing된 만화 이미지, 카툰화된 사진이 들어옴

net3 = Conv2D(kernel_size = 3,
              filters = 32,
              strides = 1,
              padding = "same"
              )(input_layer3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 64,
              strides = 2,
              padding = "same"
              )(net3)
net3 = LeakyReLU(alpha=0.2)(net3)
net3 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 1,
              padding = "same"
              )(net3)
net3 = BatchNormalization()(net3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 128,
              strides = 2,
              padding = "same"
              )(net3)
net3 = LeakyReLU(alpha=0.2)(net3)
net3 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net3)
net3 = BatchNormalization()(net3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 256,
              strides = 1,
              padding = "same"
              )(net3)
net3 = BatchNormalization()(net3)
net3 = LeakyReLU(alpha=0.2)(net3)

net3 = Conv2D(kernel_size = 3,
              filters = 1,
              strides = 1,
              padding = "same"
              )(net3)

# %%
model3 = Model(inputs = input_layer3,
              outputs = net3,
              name = "discriminator")
model3.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_33 (InputLayer)        [(None, 300, 300, 3)]     0
# _________________________________________________________________
# conv2d_662 (Conv2D)          (None, 300, 300, 32)      896
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 300, 300, 32)      0
# _________________________________________________________________
# conv2d_663 (Conv2D)          (None, 150, 150, 64)      18496
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 150, 150, 64)      0
# _________________________________________________________________
# conv2d_664 (Conv2D)          (None, 150, 150, 128)     73856
# _________________________________________________________________
# batch_normalization_561 (Bat (None, 150, 150, 128)     512
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 150, 150, 128)     0
# _________________________________________________________________
# conv2d_665 (Conv2D)          (None, 75, 75, 128)       147584
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 75, 75, 128)       0
# _________________________________________________________________
# conv2d_666 (Conv2D)          (None, 75, 75, 256)       295168
# _________________________________________________________________
# batch_normalization_562 (Bat (None, 75, 75, 256)       1024
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 75, 75, 256)       0
# _________________________________________________________________
# conv2d_667 (Conv2D)          (None, 75, 75, 256)       590080
# _________________________________________________________________
# batch_normalization_563 (Bat (None, 75, 75, 256)       1024
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 75, 75, 256)       0
# _________________________________________________________________
# conv2d_668 (Conv2D)          (None, 75, 75, 1)         2305
# =================================================================
# Total params: 1,130,945
# Trainable params: 1,129,665
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
# 출력 shape : (None, 75, 75, 1)

# compile
model3.compile(loss = loss, optimizer = optimizer, metrics = metrics)

# %% [markdown]
# # generator_web
# - 위의 generator를 훈련 데이터로 학습을 시킨 후, 그 가중치를 피클로 저장하여 generator_web만 서버에 올린다!
